# %%
import pandas as pd

# %%
df = pd.read_csv('guest_list_full.csv')

# %%
df = df[['Adults','Children', 'Plus 1?', 'Probability of adults coming','Probability of children coming (if parents are coming)']]
df
# Out:
#      Adults  Children  Plus 1?  Probability of adults coming  \
# 0         1         0        0                          1.00
# 1         1         0        0                          1.00
# 2         2         0        0                          1.00
# 3         1         0        1                          0.90
# 4         2         2        0                          1.00
# ..      ...       ...      ...                           ...
# 136       2         0        0                          0.90
# 137       2         0        0                          0.90
# 138       1         0        1                          0.60
# 139       1         0        1                          0.01
# 140       1         0        1                          0.01
#
#      Probability of children coming (if parents are coming)
# 0                                                  0.0
# 1                                                  0.0
# 2                                                  0.0
# ...

# %%
df.to_csv('guest_list_anonymized.csv', index=False)
